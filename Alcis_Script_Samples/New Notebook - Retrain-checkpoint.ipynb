# %%
import os
from pathlib import Path

import arcgis
from arcgis.gis import GIS
from arcgis.learn import prepare_data

# %%
data = prepare_data(r"D:\ArcGIS Pro\Training Data and Trained Models\Pixel-based Training Datasets and Models\Ap18", 
                    batch_size=2, 
                    chip_size=256)

# %%
data.show_batch(rows=4)

# %%
#model = arcgis.learn.models.UnetClassifier(data, backbone='resnet50', pointrend=True, pretrained_path = r"D:\ArcGIS Pro\PhD\Training Data and Trained Models\Pixel-based Training Datasets and Models\Mar18\models\1701_Pb_Mar18_Seq\1701_Pb_Mar18_Seq.pth")

# %%
model = arcgis.learn.models.UnetClassifier(data, backbone='resnet50')

# %%
lr = model.lr_find()
lr
# Out:
# 3.630780547701014e-05

# %%
model.fit(3, lr, early_stopping=True, checkpoint=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.623571</td>
#       <td>0.656499</td>
#       <td>0.721468</td>
#       <td>0.686972</td>
#       <td>09:47</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.509388</td>
#       <td>0.508062</td>
#       <td>0.794352</td>
#       <td>0.785519</td>
#       <td>09:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.499696</td>
#       <td>0.509058</td>
#       <td>0.791406</td>
#       <td>0.783580</td>
#       <td>09:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.save('1801_Pb_Apr18_Seq1')
# Out:
# Computing model metrics...
# WindowsPath('D:/ArcGIS Pro/PhD/Training Data and Trained Models/Pixel-based Training Datasets and Models/Ap18/models/1801_Pb_Apr18_Seq1')
